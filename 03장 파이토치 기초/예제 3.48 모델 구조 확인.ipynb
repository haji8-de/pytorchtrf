# %%
import torch
from torch import nn


class CustomModel(nn.Module):
    pass

# %%
class CustomModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer = nn.Linear(3, 2)

    def forward(self, x):
        x = self.layer(x)
        return x

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model = torch.load("../models/model.pt", map_location=device, weights_only=False)
print(model)
# Out:
# CustomModel(
#   (layer): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
# # 1. 모델 뼈대 만들기
# model = CustomModel().to(device)

# # 2. 가중치 데이터(state_dict)만 불러오기
# # weights_only=True는 보안상 권장되지만, 
# # 이전에 배운 에러가 발생한다면 False로 두거나 safe_globals를 사용하세요.
# weights = torch.load("../models/model.pt", map_location=device, weights_only=False)

# # 3. 뼈대에 가중치 입히기
# model.load_state_dict(weights)

# print(model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       7 weights = torch.load("../models/model.pt", map_location=device, weights_only=False)
#       9 # 3. 뼈대에 가중치 입히기
# ---> 10 model.load_state_dict(weights)
#      12 print(model)
#
# File /opt/conda/lib/python3.12/site-packages/torch/nn/modules/module.py:2525, in Module.load_state_dict(self, state_dict, strict, assign)
#    2488 r"""Copy parameters and buffers from :attr:`state_dict` into this module and its descendants.
#    2489
#    2490 If :attr:`strict` is ``True``, then
#    (...)   2522     ``RuntimeError``.
#    2523 """
#    2524 if not isinstance(state_dict, Mapping):
# -> 2525     raise TypeError(
#    2526         f"Expected state_dict to be dict-like, got {type(state_dict)}."
#    2527     )
#    2529 missing_keys: list[str] = []
#    2530 unexpected_keys: list[str] = []
#
# ...
