# %%
import torch


cpu = torch.FloatTensor([1, 2, 3])
gpu = cpu.cuda()
gpu2cpu = gpu.cpu()
cpu2gpu = cpu.to("cuda")
print(cpu)
print(gpu)
print(gpu2cpu)
print(cpu2gpu)
# Out:
# tensor([1., 2., 3.])
# tensor([1., 2., 3.], device='cuda:0')
# tensor([1., 2., 3.])
# tensor([1., 2., 3.], device='cuda:0')

# %%
# 애플 실리콘이 탑재된 맥 사용자의 경우
import torch


cpu = torch.FloatTensor([1, 2, 3])
gpu = cpu.to("mps")
gpu2cpu = gpu.cpu()
print(cpu)
print(gpu)
print(gpu2cpu)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 6
#       2 import torch
#       5 cpu = torch.FloatTensor([1, 2, 3])
# ----> 6 gpu = cpu.to("mps")
#       7 gpu2cpu = gpu.cpu()
#       8 print(cpu)
#
# RuntimeError: PyTorch is not linked with support for mps devices
